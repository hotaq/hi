# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)

# %%
# !rm -rf /content/phase-of-cell-6

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qKcHgReNUViyQ0e9n7PJ")
project = rf.workspace("chinnaphat-hwhdt").project("phase-of-cell")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.15, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to phase-of-cell-6 in yolov8:: 100%|██████████| 5176/5176 [00:01<00:00, 4087.47it/s]

# %%
# !yolo train model=yolov8n.pt data=/content/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 86.0MB/s]
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
